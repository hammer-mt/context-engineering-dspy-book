# %% [markdown]
# # DSPy Optimizer Benchmark (Chapter 6)
#
# This notebook accompanies Chapter 6 of *Context Engineering with DSPy*. It runs every optimizer the chapter walks through on the same AI text-detection task and prints the cost, time, and accuracy trade-offs.
#
# ### Expected ballpark
#
# Canonical Ch 6 reports the following on the 202-row `ai_vs_human200.csv` with `openai/gpt-4o-mini` as the task model and `openai/gpt-4o` as the teacher (baseline ~72.3%):
#
# - LabeledFewShot: ~86%
# - BootstrapFewShot: ~96%
# - BootstrapRS: ~97%
# - SIMBA / GEPA / MIPROv2: ~99%
# - COPRO: ~100%
#
# If you see numbers wildly different from these, treat it as a setup signal (wrong model slug, wrong dataset path, key not loaded) rather than a real result.
#
# ### Cost / time
#
# A full run costs roughly $5–10 across all optimizers and takes around 1.5–2 hours wall-clock with `NUM_THREADS=16`. The heavy optimizers (GEPA, MIPROv2, SIMBA, COPRO) already use `auto='light'` / small budgets in this notebook. Fine-tuning sections at the end are skipped automatically when no GPU is detected.

# %%
# Install dependencies
# %pip install -r ../requirements.txt -q

# %%
import dspy
import pandas as pd
import time
import os
import random
import copy
import json
import pickle
import threading
import contextlib
import signal
import sys
import time as time_module
from concurrent.futures import FIRST_COMPLETED, ThreadPoolExecutor, wait
import tqdm
import logging
from dotenv import load_dotenv
from dataclasses import dataclass, field
from typing import Any
from pathlib import Path

# Load environment variables
load_dotenv()

# Create output directory for saved programs
PROGRAMS_DIR = Path("optimized_programs")
PROGRAMS_DIR.mkdir(exist_ok=True)

# Pricing per 1M tokens (as of Dec 2025)
# Source: https://openai.com/api/pricing/
PRICING = {
    "openai/gpt-4o-mini": {"input": 0.15, "output": 0.60},
    "openai/gpt-4o": {"input": 2.50, "output": 10.00},
}

NUM_THREADS = 16

def calculate_cost(usage: dict) -> float:
    """Calculate cost from usage dict."""
    total_cost = 0.0
    for model, data in usage.items():
        if model in PRICING:
            prompt_tokens = data.get("prompt_tokens", 0)
            completion_tokens = data.get("completion_tokens", 0)
            total_cost += (prompt_tokens / 1_000_000) * PRICING[model]["input"]
            total_cost += (completion_tokens / 1_000_000) * PRICING[model]["output"]
    return total_cost

# %%
# =============================================================================
# Monkey-patch for DSPy parallelizer bug (affects dspy.track_usage())
# 
# Bug: Line 95 in parallelizer.py tries to access thread_local_overrides.overrides
# which doesn't exist (ContextVar has no .overrides attribute). This silently
# breaks context propagation to worker threads.
#
# Fix: Build the complete overrides dict BEFORE calling set(), and don't deep
# copy the usage_tracker so it's shared across threads.
# =============================================================================
from dspy.utils.parallelizer import ParallelExecutor
from dspy.dsp.utils.settings import thread_local_overrides

_logger = logging.getLogger(__name__)

def _fixed_execute_parallel(self, function, data):
    """Fixed version of ParallelExecutor._execute_parallel."""
    results = [None] * len(data)
    job_cancelled = "cancelled"
    start_time_map = {}
    start_time_lock = threading.Lock()
    resubmitted = set()
    
    parent_overrides = thread_local_overrides.get().copy()

    def worker(parent_ovr, submission_id, index, item):
        if self.cancel_jobs.is_set():
            return index, job_cancelled
        with start_time_lock:
            start_time_map[submission_id] = time_module.time()

        original = thread_local_overrides.get()
        # FIX: Build complete overrides dict BEFORE calling set()
        # Don't deep copy usage_tracker - share it across threads for aggregation
        new_overrides = {**original, **parent_ovr}
        token = thread_local_overrides.set(new_overrides)

        try:
            return index, function(item)
        finally:
            thread_local_overrides.reset(token)

    @contextlib.contextmanager
    def interrupt_manager():
        if threading.current_thread() is threading.main_thread():
            orig_handler = signal.getsignal(signal.SIGINT)
            def handler(sig, frame):
                self.cancel_jobs.set()
                _logger.warning("SIGINT received. Cancelling.")
                orig_handler(sig, frame)
            signal.signal(signal.SIGINT, handler)
            try:
                yield
            finally:
                signal.signal(signal.SIGINT, orig_handler)
        else:
            yield

    executor = ThreadPoolExecutor(max_workers=self.num_threads)
    try:
        with interrupt_manager():
            futures_map = {}
            futures_set = set()
            submission_counter = 0

            for idx, item in enumerate(data):
                f = executor.submit(worker, parent_overrides, submission_counter, idx, item)
                futures_map[f] = (submission_counter, idx, item)
                futures_set.add(f)
                submission_counter += 1

            pbar = tqdm.tqdm(
                total=len(data),
                dynamic_ncols=True,
                disable=self.disable_progress_bar,
                file=sys.stdout,
            )

            def all_done():
                return all(r is not None for r in results)

            while futures_set and not self.cancel_jobs.is_set():
                if all_done():
                    break
                done, not_done = wait(futures_set, timeout=1, return_when=FIRST_COMPLETED)
                for f in done:
                    futures_set.remove(f)
                    try:
                        index, outcome = f.result()
                    except Exception:
                        pass
                    else:
                        if outcome != job_cancelled and results[index] is None:
                            if isinstance(outcome, Exception):
                                with self.error_lock:
                                    self.failed_indices.append(index)
                                    self.exceptions_map[index] = outcome
                                results[index] = None
                            else:
                                results[index] = outcome

                        if self.compare_results:
                            vals = [r[-1] for r in results if r is not None]
                            self._update_progress(pbar, sum(vals), len(vals))
                        else:
                            self._update_progress(pbar, len([r for r in results if r is not None]), len(data))

                if all_done():
                    break

                if 0 < self.timeout and len(not_done) <= self.straggler_limit:
                    now = time_module.time()
                    for f in list(not_done):
                        if f not in resubmitted:
                            sid, idx, item = futures_map[f]
                            with start_time_lock:
                                st = start_time_map.get(sid, None)
                            if st and (now - st) >= self.timeout:
                                resubmitted.add(f)
                                nf = executor.submit(worker, parent_overrides, submission_counter, idx, item)
                                futures_map[nf] = (submission_counter, idx, item)
                                futures_set.add(nf)
                                submission_counter += 1

            pbar.close()

    finally:
        executor.shutdown(wait=False)

    if self.cancel_jobs.is_set():
        _logger.warning("Execution cancelled due to errors or interruption.")
        raise Exception("Execution cancelled due to errors or interruption.")

    return results

# Apply the fix
ParallelExecutor._execute_parallel = _fixed_execute_parallel
print("Applied DSPy parallelizer fix for usage tracking")

# %%
# Initialize models
task_lm = dspy.LM(
    "openai/gpt-4o-mini",
    api_key=os.getenv("OPENAI_API_KEY"),
    temperature=1.0,
    max_tokens=16000,
    cache=False  # In order to track latency and cost
)

teacher_lm = dspy.LM(
    "openai/gpt-4o",  # Teacher/reflection model
    api_key=os.getenv("OPENAI_API_KEY"),
    temperature=1.0,
    max_tokens=16000,
    cache=False  # In order to track latency and cost
)

# Configure default LM
dspy.configure(lm=task_lm)

# %%
# Load dataset (same as dspy-in-8-steps.ipynb)
csv_path = '../data/ai_vs_human200.csv'
df = pd.read_csv(csv_path)
examples = df.to_dict(orient='records')

# Convert to DSPy Examples
dataset = [
    dspy.Example(**ex).with_inputs("text")
    for ex in examples
]

# Reproducible shuffle and 3-way split: train/val/test
random.seed(42)
random.shuffle(dataset)

n = len(dataset)
train_end = int(n * 0.5)   # 50% for training
val_end = int(n * 0.75)    # 25% for validation (optimizer tuning)
                            # 25% for test (final generalization)

trainset = dataset[:train_end]
valset = dataset[train_end:val_end]
testset = dataset[val_end:]

print(f"Loaded: {csv_path}")
print(f"Training set:   {len(trainset)} examples (for bootstrapping demos)")
print(f"Validation set: {len(valset)} examples (for optimizer tuning)")
print(f"Test set:       {len(testset)} examples (for final evaluation)")

# %%
# Define Signature and Module (same as dspy-in-8-steps.ipynb)
class DetectAIText(dspy.Signature):
    """Detects whether text is AI-generated."""
    text: str = dspy.InputField(description="The text to analyze")
    is_ai: bool = dspy.OutputField(description="Whether the text is AI-generated")


class AIDetector(dspy.Module):
    def __init__(self):
        super().__init__()
        # Chain of thought reasoning
        self.detect = dspy.ChainOfThought(DetectAIText)

    def forward(self, text: str):
        return self.detect(text=text)

# %%
# Define metrics (same as dspy-in-8-steps.ipynb)

# Standard exact match metric
def exact_match(example, response, trace=None):
    return 1 if example.is_ai == response.is_ai else 0


# Exact match metric with feedback for GEPA
def exact_match_with_feedback(example, response, trace=None, pred_name=None, pred_trace=None):
    score = 1 if example.is_ai == response.is_ai else 0
    if pred_name:
        return dspy.Prediction(score=score, feedback=example.notes)
    else:
        return score

# %%
@dataclass
class BenchmarkResult:
    """Results from benchmarking an optimizer."""
    optimizer_name: str
    baseline_accuracy: float
    optimized_accuracy: float
    accuracy_uplift: float
    total_tokens: int
    prompt_tokens: int
    completion_tokens: int
    cost_usd: float
    time_seconds: float
    notes: str = ""
    usage_by_model: dict = field(default_factory=dict)
    program: Any = None  # Store the optimized program


def run_baseline_evaluation(module_class, devset, metric):
    """Run baseline evaluation and return accuracy."""
    detector = module_class()
    evaluator = dspy.Evaluate(
        devset=devset,
        metric=metric,
        num_threads=NUM_THREADS,
        display_progress=True,
        display_table=False,
    )
    result = evaluator(detector)
    return result.score / 100  # Convert percentage to decimal


def evaluate_optimized(optimized_module, devset, metric):
    """Evaluate optimized module and return accuracy."""
    evaluator = dspy.Evaluate(
        devset=devset,
        metric=metric,
        num_threads=NUM_THREADS,
        display_progress=True,
        display_table=False,
    )
    result = evaluator(optimized_module)
    return result.score / 100


def print_benchmark_result(result: BenchmarkResult):
    """Print benchmark results in a standard format."""
    print("\n" + "="*60)
    print(f"OPTIMIZER: {result.optimizer_name}")
    print("="*60)
    print(f"Baseline Accuracy:   {result.baseline_accuracy*100:.1f}%")
    print(f"Optimized Accuracy:  {result.optimized_accuracy*100:.1f}%")
    print(f"Accuracy Uplift:     {result.accuracy_uplift*100:+.1f}%")
    print("-"*60)
    print(f"Total Tokens:        {result.total_tokens:,}")
    print(f"  - Prompt:          {result.prompt_tokens:,}")
    print(f"  - Completion:      {result.completion_tokens:,}")
    print(f"Estimated Cost:      ${result.cost_usd:.4f}")
    print(f"Time Taken:          {result.time_seconds:.1f}s")
    if result.notes:
        print(f"Notes:               {result.notes}")
    print("="*60 + "\n")


def save_program(program, name: str):
    """Save program with demos and instructions to disk."""
    # Save human-readable JSON with program details
    json_path = PROGRAMS_DIR / f"{name}.json"

    # Extract program details for inspection
    program_info = {
        "name": name,
        "predictors": []
    }

    for pred_name, predictor in program.named_predictors():
        pred_info = {
            "name": pred_name,
            "signature": str(predictor.signature) if hasattr(predictor, 'signature') else None,
            "instructions": predictor.signature.instructions if hasattr(predictor, 'signature') and hasattr(predictor.signature, 'instructions') else None,
            "demos": []
        }

        if hasattr(predictor, 'demos') and predictor.demos:
            for demo in predictor.demos:
                # Convert demo to serializable format
                demo_dict = {}
                if isinstance(demo, dict):
                    demo_dict = {k: str(v) if not isinstance(v, (str, int, float, bool, type(None))) else v for k, v in demo.items()}
                elif hasattr(demo, 'toDict'):
                    demo_dict = {k: str(v) if not isinstance(v, (str, int, float, bool, type(None))) else v for k, v in demo.toDict().items()}
                elif hasattr(demo, '__dict__'):
                    demo_dict = {k: str(v) if not isinstance(v, (str, int, float, bool, type(None))) else v for k, v in demo.__dict__.items()}
                pred_info["demos"].append(demo_dict)

        program_info["predictors"].append(pred_info)

    with open(json_path, 'w') as f:
        json.dump(program_info, f, indent=2, default=str)

    # Use DSPy's native save method for full restoration
    dspy_path = PROGRAMS_DIR / f"{name}.dspy"
    try:
        program.save(str(dspy_path))
        print(f"Saved program to {json_path} and {dspy_path}")
    except Exception as e:
        print(f"Saved program to {json_path} (DSPy save failed: {e})")

    return json_path


def display_program_details(program, name: str):
    """Display program demos and instructions."""
    print(f"\n{'='*60}")
    print(f"PROGRAM DETAILS: {name}")
    print("="*60)
    
    for pred_name, predictor in program.named_predictors():
        print(f"\nPredictor: {pred_name}")
        print("-"*40)
        
        if hasattr(predictor, 'signature') and hasattr(predictor.signature, 'instructions'):
            instr = predictor.signature.instructions
            if instr:
                print(f"Instructions: {instr[:200]}..." if len(instr) > 200 else f"Instructions: {instr}")
        
        if hasattr(predictor, 'demos') and predictor.demos:
            print(f"Number of demos: {len(predictor.demos)}")
            for i, demo in enumerate(predictor.demos[:2]):  # Show first 2
                print(f"  Demo {i+1}: {str(demo)[:100]}...")
            if len(predictor.demos) > 2:
                print(f"  ... and {len(predictor.demos) - 2} more demos")
        else:
            print("Number of demos: 0")
    print()


# Store all results for final comparison
all_results: list[BenchmarkResult] = []

# Store all optimized programs
optimized_programs: dict[str, Any] = {}

# %% [markdown]
# ## Baseline Evaluation
#
# First, let's establish our baseline accuracy on the **test set** without any optimization.

# %%
# Run baseline evaluation on test set
print("Running baseline evaluation on test set...")
baseline_accuracy = run_baseline_evaluation(AIDetector, testset, exact_match)

print(f"\nBaseline accuracy (test set): {baseline_accuracy*100:.1f}%")

# %% [markdown]
# ---
# ## 1. LabeledFewShot
#
# The simplest optimizer - just adds labeled examples as few-shot demonstrations. No metric needed.

# %%
from dspy.teleprompt import LabeledFewShot

print("Running LabeledFewShot optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = LabeledFewShot(k=4)
    program_labeledfewshot = optimizer.compile(
        AIDetector(),
        trainset=trainset
    )
    
    # Evaluate on TEST set (not validation)
    optimized_accuracy = evaluate_optimized(program_labeledfewshot, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

# Calculate totals
total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_labeledfewshot = BenchmarkResult(
    optimizer_name="LabeledFewShot",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="No metric required. Simply adds k random examples as demos.",
    usage_by_model=total_usage,
    program=program_labeledfewshot,
)

print_benchmark_result(result_labeledfewshot)
display_program_details(program_labeledfewshot, "LabeledFewShot")
save_program(program_labeledfewshot, "labeledfewshot")

all_results.append(result_labeledfewshot)
optimized_programs["labeledfewshot"] = program_labeledfewshot

# %% [markdown]
# ---
# ## 2. KNNFewShot
#
# Uses embedding-based nearest neighbor search to select the most relevant demos for each input at inference time.

# %%
# KNNFewShot requires sentence-transformers which has compatibility issues
# with some torch versions. Skipping for now.
print("Skipping KNNFewShot - requires sentence-transformers (compatibility issues with current torch)")
print("To enable: pip install sentence-transformers and fix torch version compatibility")

# Placeholder result
result_knnfewshot = BenchmarkResult(
    optimizer_name="KNNFewShot",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=0,
    accuracy_uplift=0,
    total_tokens=0,
    prompt_tokens=0,
    completion_tokens=0,
    cost_usd=0,
    time_seconds=0,
    notes="SKIPPED: Requires sentence-transformers (torch version compatibility issues)",
    usage_by_model={},
    program=None,
)

all_results.append(result_knnfewshot)

# %% [markdown]
# ---
# ## 3. BootstrapFewShot
#
# Bootstraps demonstrations by running the teacher on training examples and selecting successful traces.

# %%
from dspy.teleprompt import BootstrapFewShot

print("Running BootstrapFewShot optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = BootstrapFewShot(
        metric=exact_match,
        max_bootstrapped_demos=4,
        max_labeled_demos=4,
        max_rounds=1,
    )
    program_bootstrapfewshot = optimizer.compile(
        AIDetector(),
        trainset=trainset,
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_bootstrapfewshot, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_bootstrapfewshot = BenchmarkResult(
    optimizer_name="BootstrapFewShot",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Bootstraps successful traces as demonstrations.",
    usage_by_model=total_usage,
    program=program_bootstrapfewshot,
)

print_benchmark_result(result_bootstrapfewshot)
display_program_details(program_bootstrapfewshot, "BootstrapFewShot")
save_program(program_bootstrapfewshot, "bootstrapfewshot")

all_results.append(result_bootstrapfewshot)
optimized_programs["bootstrapfewshot"] = program_bootstrapfewshot

# %% [markdown]
# ---
# ## 4. BootstrapFewShotWithOptuna
#
# Uses Optuna to search over demo combinations after bootstrapping.

# %%
from dspy.teleprompt import BootstrapFewShotWithOptuna

print("Running BootstrapFewShotWithOptuna optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = BootstrapFewShotWithOptuna(
        metric=exact_match,
        max_bootstrapped_demos=8,  # Bootstrap more demos for Optuna to select from
        max_labeled_demos=4,
        max_rounds=1,
        num_candidate_programs=10,  # Number of Optuna trials
        num_threads=NUM_THREADS,
    )
    program_bootstrapoptuna = optimizer.compile(
        AIDetector(),
        max_demos=8,
        trainset=trainset,
        valset=valset,  # Use valset for Optuna optimization
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_bootstrapoptuna, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_bootstrapoptuna = BenchmarkResult(
    optimizer_name="BootstrapFewShotWithOptuna",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Uses Optuna to search over demo combinations.",
    usage_by_model=total_usage,
    program=program_bootstrapoptuna,
)

print_benchmark_result(result_bootstrapoptuna)
display_program_details(program_bootstrapoptuna, "BootstrapFewShotWithOptuna")
save_program(program_bootstrapoptuna, "bootstrapoptuna")

all_results.append(result_bootstrapoptuna)
optimized_programs["bootstrapoptuna"] = program_bootstrapoptuna

# %% [markdown]
# ---
# ## 5. BootstrapFewShotWithRandomSearch
#
# Tries multiple random configurations of bootstrapped demos and selects the best.

# %%
from dspy.teleprompt import BootstrapFewShotWithRandomSearch

print("Running BootstrapFewShotWithRandomSearch optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = BootstrapFewShotWithRandomSearch(
        metric=exact_match,
        max_bootstrapped_demos=4,
        max_labeled_demos=4,
        max_rounds=1,
        num_candidate_programs=8,
        num_threads=NUM_THREADS,
    )
    program_bootstraprs = optimizer.compile(
        AIDetector(),
        trainset=trainset,
        valset=valset,  # Use valset for candidate selection
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_bootstraprs, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_bootstraprs = BenchmarkResult(
    optimizer_name="BootstrapFewShotWithRandomSearch",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Random search over demo configurations.",
    usage_by_model=total_usage,
    program=program_bootstraprs,
)

print_benchmark_result(result_bootstraprs)
display_program_details(program_bootstraprs, "BootstrapFewShotWithRandomSearch")
save_program(program_bootstraprs, "bootstraprs")

all_results.append(result_bootstraprs)
optimized_programs["bootstraprs"] = program_bootstraprs

# %% [markdown]
# ---
# ## 6. InferRules
#
# Infers natural language rules from training examples and adds them to the instructions.

# %%
from dspy.teleprompt import InferRules

print("Running InferRules optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    # InferRules uses the teacher LM for rule induction
    optimizer = InferRules(
        metric=exact_match,
        num_candidates=5,  # Number of candidate rule sets to try
        num_rules=5,       # Number of rules to generate
        num_threads=NUM_THREADS,
        teacher_settings={"lm": teacher_lm},
    )
    program_inferrules = optimizer.compile(
        AIDetector(),
        trainset=trainset,
        valset=valset,  # Use valset for candidate selection
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_inferrules, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_inferrules = BenchmarkResult(
    optimizer_name="InferRules",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Infers natural language rules from examples. Uses gpt-4o for rule generation.",
    usage_by_model=total_usage,
    program=program_inferrules,
)

print_benchmark_result(result_inferrules)
display_program_details(program_inferrules, "InferRules")
save_program(program_inferrules, "inferrules")

all_results.append(result_inferrules)
optimized_programs["inferrules"] = program_inferrules

# %% [markdown]
# ---
# ## 7. COPRO
#
# Optimizes instructions using an iterative refinement approach.

# %%
from dspy.teleprompt import COPRO

print("Running COPRO optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = COPRO(
        prompt_model=teacher_lm,
        metric=exact_match,
        breadth=5,
        depth=2,
        init_temperature=1.0,
        track_stats=True,
    )
    program_copro = optimizer.compile(
        AIDetector(),
        trainset=trainset,  # COPRO uses trainset for evaluation during optimization
        eval_kwargs={"num_threads": NUM_THREADS, "display_progress": True, "display_table": False},
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_copro, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_copro = BenchmarkResult(
    optimizer_name="COPRO",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes=f"Uses gpt-4o for instruction generation. depth={optimizer.depth}, breadth={optimizer.breadth}",
    usage_by_model=total_usage,
    program=program_copro,
)

print_benchmark_result(result_copro)
display_program_details(program_copro, "COPRO")
save_program(program_copro, "copro")

all_results.append(result_copro)
optimized_programs["copro"] = program_copro

# %% [markdown]
# ---
# ## 8. MIPROv2
#
# Combines instruction optimization with few-shot demo selection using Bayesian optimization (Optuna).

# %%
from dspy.teleprompt import MIPROv2

print("Running MIPROv2 optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = MIPROv2(
        metric=exact_match,
        prompt_model=teacher_lm,
        task_model=task_lm,
        auto="light",
        num_threads=NUM_THREADS,
        max_bootstrapped_demos=4,
        max_labeled_demos=4,
        track_stats=True,
    )
    program_miprov2 = optimizer.compile(
        AIDetector(),
        trainset=trainset,
        valset=valset,  # Use valset for Bayesian optimization
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_miprov2, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_miprov2 = BenchmarkResult(
    optimizer_name="MIPROv2",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Uses gpt-4o for instruction generation. auto='light' preset.",
    usage_by_model=total_usage,
    program=program_miprov2,
)

print_benchmark_result(result_miprov2)
display_program_details(program_miprov2, "MIPROv2")
save_program(program_miprov2, "miprov2")

all_results.append(result_miprov2)
optimized_programs["miprov2"] = program_miprov2

# %% [markdown]
# ---
# ## 9. GEPA
#
# Evolutionary optimizer that uses reflection to evolve instructions based on feedback.

# %%
from dspy.teleprompt import GEPA

print("Running GEPA optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    optimizer = GEPA(
        metric=exact_match_with_feedback,
        auto="light",
        reflection_lm=teacher_lm,
        num_threads=4,
        track_stats=True,
        use_merge=False,
    )
    program_gepa = optimizer.compile(
        AIDetector(),
        trainset=trainset,
        valset=valset,
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_gepa, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_gepa = BenchmarkResult(
    optimizer_name="GEPA",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Evolutionary optimizer with reflection. Uses gpt-4o for reflection.",
    usage_by_model=total_usage,
    program=program_gepa,
)

print_benchmark_result(result_gepa)
display_program_details(program_gepa, "GEPA")
save_program(program_gepa, "gepa")

all_results.append(result_gepa)
optimized_programs["gepa"] = program_gepa

# %% [markdown]
# ---
# ## 10. SIMBA
#
# Stochastic Introspective Mini-Batch Ascent - uses LLM to analyze performance and generate improvement rules.

# %%
from dspy.teleprompt import SIMBA

print("Running SIMBA optimizer...")

start_time = time.time()
with dspy.track_usage() as usage:
    # Basic SIMBA config (older version without prompt_model/teacher_settings)
    optimizer = SIMBA(
        metric=exact_match,
        bsize=8,
        num_candidates=4,
        max_steps=3,
        max_demos=4,
        num_threads=4,
    )
    program_simba = optimizer.compile(
        AIDetector(),
        trainset=trainset,
        seed=42,
    )
    
    # Evaluate on TEST set
    optimized_accuracy = evaluate_optimized(program_simba, testset, exact_match)

elapsed = time.time() - start_time
total_usage = usage.get_total_tokens()

total_tokens = sum(d.get("total_tokens", 0) for d in total_usage.values())
prompt_tokens = sum(d.get("prompt_tokens", 0) for d in total_usage.values())
completion_tokens = sum(d.get("completion_tokens", 0) for d in total_usage.values())

result_simba = BenchmarkResult(
    optimizer_name="SIMBA",
    baseline_accuracy=baseline_accuracy,
    optimized_accuracy=optimized_accuracy,
    accuracy_uplift=optimized_accuracy - baseline_accuracy,
    total_tokens=total_tokens,
    prompt_tokens=prompt_tokens,
    completion_tokens=completion_tokens,
    cost_usd=calculate_cost(total_usage),
    time_seconds=elapsed,
    notes="Mini-batch ascent with self-reflection. Uses default task LM.",
    usage_by_model=total_usage,
    program=program_simba,
)

print_benchmark_result(result_simba)
display_program_details(program_simba, "SIMBA")
save_program(program_simba, "simba")

all_results.append(result_simba)
optimized_programs["simba"] = program_simba

# %% [markdown]
# ---
# ## Note on AvatarOptimizer
#
# **AvatarOptimizer** is designed specifically for tool-using agents (Avatar modules). It optimizes instructions for agents that take actions using tools.
#
# Since our AI text detection task uses a simple ChainOfThought module (no tools/actions), AvatarOptimizer is not applicable here. It would require:
# 1. An Avatar-based module with `.tools` attribute
# 2. An `.actor` with a signature containing instructions
# 3. Predictions that return `.actions`
#
# If you have a tool-using agent, AvatarOptimizer can be used like this:
#
# ```python
# from dspy.teleprompt import AvatarOptimizer
#
# optimizer = AvatarOptimizer(
#     metric=your_metric,
#     max_iters=10,
#     lower_bound=0,
#     upper_bound=1,
# )
# optimized_agent = optimizer.compile(your_avatar_module, trainset=trainset)
# ```

# %% [markdown]
# ---
# ## Fine-tuning Optimizers (Require Training Infrastructure)
#
# The following optimizers require **actual model fine-tuning** (not just inference). They will NOT work with:
# - LM Studio (inference only)
# - Ollama (inference only)
# - Standard OpenAI/Anthropic APIs
#
# See the original notebook for setup instructions for GRPO, BootstrapFinetune, and BetterTogether.

# %%
# Check if fine-tuning infrastructure is available
import subprocess
import shutil

BOOTSTRAPFINETUNE_AVAILABLE = False
GRPO_AVAILABLE = False
LOCAL_MODEL = "Qwen/Qwen2.5-1.5B-Instruct"

# Check for GPU
try:
    import torch
    if torch.cuda.is_available():
        gpu_name = torch.cuda.get_device_name(0)
        gpu_count = torch.cuda.device_count()
        vram = torch.cuda.get_device_properties(0).total_memory / 1e9
        print(f"GPU available: {gpu_name}")
        print(f"GPU count: {gpu_count}")
        print(f"VRAM per GPU: {vram:.1f} GB")
        BOOTSTRAPFINETUNE_AVAILABLE = True
        if gpu_count >= 2:
            GRPO_AVAILABLE = True
    else:
        print("No GPU available.")
except ImportError:
    print("PyTorch not installed.")

print(f"\nLocal model: {LOCAL_MODEL}")
print(f"BootstrapFinetune available: {BOOTSTRAPFINETUNE_AVAILABLE}")
print(f"GRPO available: {GRPO_AVAILABLE}")

if not BOOTSTRAPFINETUNE_AVAILABLE and not GRPO_AVAILABLE:
    print("\nFine-tuning optimizers will be skipped. See setup instructions above.")

# %% [markdown]
# ---
# ## Summary: Optimizer Comparison
#
# Final comparison of all optimizers across all metrics. **All evaluations are on the held-out test set.**

# %%
# Create summary DataFrame
summary_data = []
for r in all_results:
    summary_data.append({
        "Optimizer": r.optimizer_name,
        "Baseline Acc": f"{r.baseline_accuracy*100:.1f}%",
        "Test Acc": f"{r.optimized_accuracy*100:.1f}%" if r.optimized_accuracy > 0 else "N/A",
        "Uplift": f"{r.accuracy_uplift*100:+.1f}%" if r.optimized_accuracy > 0 else "N/A",
        "Tokens": f"{r.total_tokens:,}" if r.total_tokens > 0 else "N/A",
        "Cost": f"${r.cost_usd:.2f}" if r.cost_usd > 0 else "N/A",
        "Time (s)": f"{r.time_seconds:.1f}" if r.time_seconds > 0 else "N/A",
    })

summary_df = pd.DataFrame(summary_data)

print("\n" + "="*100)
print("OPTIMIZER BENCHMARK SUMMARY (v2)")
print("="*100)
print(f"\nTask Model: openai/gpt-4o-mini")
print(f"Teacher/Reflection Model: openai/gpt-4o")
print(f"\nData Split:")
print(f"  Training:   {len(trainset)} examples (for bootstrapping demos)")
print(f"  Validation: {len(valset)} examples (for optimizer tuning)")
print(f"  Test:       {len(testset)} examples (for final evaluation)")
print("\n")

# Display with pandas
pd.set_option('display.max_colwidth', 60)
print(summary_df.to_string(index=False))

# Find best optimizer
valid_results = [r for r in all_results if r.optimized_accuracy > 0]
if valid_results:
    best_by_accuracy = max(valid_results, key=lambda r: r.accuracy_uplift)
    most_efficient = min(valid_results, key=lambda r: r.cost_usd if r.cost_usd > 0 else float('inf'))
    
    print("\n" + "-"*100)
    print(f"Best by Test Accuracy Uplift: {best_by_accuracy.optimizer_name} ({best_by_accuracy.accuracy_uplift*100:+.1f}%)")
    print(f"Most Cost Efficient: {most_efficient.optimizer_name} (${most_efficient.cost_usd:.2f})")
    print("-"*100)

# %%
# Detailed token usage breakdown
print("\n" + "="*80)
print("DETAILED TOKEN USAGE BY MODEL")
print("="*80)

for r in all_results:
    if r.usage_by_model:
        print(f"\n{r.optimizer_name}:")
        for model, usage in r.usage_by_model.items():
            prompt = usage.get('prompt_tokens', 0)
            completion = usage.get('completion_tokens', 0)
            total = usage.get('total_tokens', prompt + completion)
            print(f"  {model}:")
            print(f"    Prompt tokens:     {prompt:,}")
            print(f"    Completion tokens: {completion:,}")
            print(f"    Total tokens:      {total:,}")

# %%
# Save results to CSV
results_df = pd.DataFrame([{
    "optimizer": r.optimizer_name,
    "baseline_accuracy": r.baseline_accuracy,
    "test_accuracy": r.optimized_accuracy,
    "accuracy_uplift": r.accuracy_uplift,
    "total_tokens": r.total_tokens,
    "prompt_tokens": r.prompt_tokens,
    "completion_tokens": r.completion_tokens,
    "cost_usd": r.cost_usd,
    "time_seconds": r.time_seconds,
    "notes": r.notes,
} for r in all_results])

results_df.to_csv("optimizer_benchmark_v2_results.csv", index=False)
print("Results saved to optimizer_benchmark_v2_results.csv")

# %%
# Inspect saved programs
print("\n" + "="*80)
print("SAVED OPTIMIZED PROGRAMS")
print("="*80)
print(f"\nPrograms saved to: {PROGRAMS_DIR.absolute()}")
print("\nAvailable programs:")
for name, prog in optimized_programs.items():
    json_path = PROGRAMS_DIR / f"{name}.json"
    dspy_path = PROGRAMS_DIR / f"{name}.dspy"
    print(f"  - {name}")
    print(f"      JSON (readable):  {json_path}")
    print(f"      DSPy (loadable):  {dspy_path}")

print("\nTo load a program:")
print("  program = AIDetector()")
print("  program.load('optimized_programs/miprov2.dspy')")

# %%
# View the optimized instructions from each optimizer
print("\n" + "="*80)
print("OPTIMIZED INSTRUCTIONS COMPARISON")
print("="*80)

for name, prog in optimized_programs.items():
    print(f"\n{'='*60}")
    print(f"{name.upper()}")
    print("="*60)
    
    for pred_name, predictor in prog.named_predictors():
        if hasattr(predictor, 'signature') and hasattr(predictor.signature, 'instructions'):
            instr = predictor.signature.instructions
            if instr:
                print(f"\nPredictor: {pred_name}")
                print("-"*40)
                print(instr[:500])
                if len(instr) > 500:
                    print(f"\n... ({len(instr) - 500} more characters)")
